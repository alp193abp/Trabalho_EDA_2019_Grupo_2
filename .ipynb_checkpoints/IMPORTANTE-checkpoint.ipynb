# %%
import DICT1
import DICT2
import _pickle as cP

# %%
a=open('englishText_0_10000',encoding='latin-1')
b=a.read()

# %%
c=DICT1.id_texts(b)

# %%
c[0]
# Out:
# ["'night, Mother",
# ...

# %%
d=DICT2.word_id(c)

# %%
f=open('Abc','wb')
cP.dump(d,f,2)
f.close()

# %%
g=open('Abc','rb')
x=cP.load(g)
g.close()

# %%
# Out:
# [0,
#  1,
#  2,
#  4,
#  10,
#  11,
#  21,
#  31,
#  36,
#  37,
#  42,
#  43,
#  44,
#  48,
#  51,
#  52,
#  53,
#  54,
#  56,
#  57,
#  58,
#  60,
#  61,
#  64,
#  65,
#  68,
#  70,
#  77,
#  80,
#  87,
#  90,
#  92,
#  93,
#  95,
#  96,
#  98,
#  99,
#  101,
#  105,
#  107,
#  109,
#  111,
#  117,
#  119,
#  120,
#  121,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  133,
#  134,
#  135,
#  137,
#  138,
#  139,
#  146,
#  147,
#  148,
#  149,
#  151,
#  152,
#  153,
#  155,
#  164,
#  165,
#  166,
#  168,
#  170,
#  172,
#  174,
#  175,
#  177,
#  179,
#  180,
#  182,
#  183,
#  184,
#  185,
#  186,
#  189,
#  190,
#  192,
#  193,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  203,
#  205,
#  206,
#  207,
#  213,
#  221,
#  222,
#  223,
#  225,
#  226,
#  227,
#  230,
#  232,
#  233,
#  238,
#  239,
#  240,
#  241,
#  243,
#  245,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  257,
#  258,
#  260,
#  261,
#  262,
#  263,
#  268,
# ...
